# %%
from dotenv import load_dotenv
load_dotenv("../.env")
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0,
    # other params...
)

# %% [markdown]
# ### Loading the Image

# %%
# %pip install pytesseract
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"D:\Software\tesseract.exe"

# %%
from PIL import Image
from io import BytesIO

image = Image.open("../IMG_20240817_172625.png")
buffered = BytesIO()
image.save(buffered, format="PNG")
image_bytes = buffered.getvalue()

# %%
len(image_bytes)
# Out:
# 950133

# %%
from langchain_core.prompts import PromptTemplate

template = "Describe the image in two lines: {image}"
prompt = PromptTemplate(template = template, input_variables=["image"])

chain = prompt | llm

# %%
result = chain.invoke({"image": data})

# %%
result
# Out:
# AIMessage(content="The image contains two rectangular sections, one on the left and one on the right. The left section appears to be a close-up of a person's face, while the right section shows a larger image with a lower detection probability. \n", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}]}, id='run-ab601352-7f28-4895-a6bb-6e211e2e7393-0', usage_metadata={'input_tokens': 717, 'output_tokens': 48, 'total_tokens': 765})

# %%
import base64
with open(image, "rb") as image_file:
    image_data = base64.b64encode(image_file.read()).decode("utf-8")

# %%
print(image_data)
# Out:
# ...

# %%
# %pip install --upgrade --quiet "unstructured[all-docs]"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders.image import UnstructuredImageLoader

loader = UnstructuredImageLoader("C:\\Users\\madhe\\OneDrive\\Desktop\\personal docs\\Pan.jpg", mode= "elements")

data = loader.load()

data[0]
# Out:
# Document(metadata={'source': 'C:\\Users\\madhe\\OneDrive\\Desktop\\personal docs\\Pan.jpg', 'detection_class_prob': 0.3080345094203949, 'coordinates': {'points': ((32.395423889160156, 186.31031799316406), (32.395423889160156, 455.01605224609375), (281.2545166015625, 455.01605224609375), (281.2545166015625, 186.31031799316406)), 'system': 'PixelSpace', 'layout_width': 1280, 'layout_height': 784}, 'last_modified': '2023-07-28T13:32:44', 'filetype': 'JPEG', 'languages': ['eng'], 'page_number': 1, 'file_directory': 'C:\\Users\\madhe\\OneDrive\\Desktop\\personal docs', 'filename': 'Pan.jpg', 'category': 'Image', 'element_id': '71d0650e64d6dacc452f5257723d0d2d'}, page_content='')

# %%
data
# Out:
# [Document(metadata={'source': 'C:\\Users\\madhe\\OneDrive\\Desktop\\personal docs\\Pan.jpg', 'detection_class_prob': 0.3080345094203949, 'coordinates': {'points': ((32.395423889160156, 186.31031799316406), (32.395423889160156, 455.01605224609375), (281.2545166015625, 455.01605224609375), (281.2545166015625, 186.31031799316406)), 'system': 'PixelSpace', 'layout_width': 1280, 'layout_height': 784}, 'last_modified': '2023-07-28T13:32:44', 'filetype': 'JPEG', 'languages': ['eng'], 'page_number': 1, 'file_directory': 'C:\\Users\\madhe\\OneDrive\\Desktop\\personal docs', 'filename': 'Pan.jpg', 'category': 'Image', 'element_id': '71d0650e64d6dacc452f5257723d0d2d'}, page_content=''),
#  Document(metadata={'source': 'C:\\Users\\madhe\\OneDrive\\Desktop\\personal docs\\Pan.jpg', 'detection_class_prob': 0.8477708697319031, 'coordinates': {'points': ((876.7171630859375, 236.7450408935547), (876.7171630859375, 560.1875), (1218.842041015625, 560.1875), (1218.842041015625, 236.7450408935547)), 'system': 'PixelSpace', 'layout_width': 1280, 'layout_height': 784}, 'last_modified': '2023-07-28T13:32:44', 'filetype': 'JPEG', 'languages': ['eng'], 'page_number': 1, 'file_directory': 'C:\\Users\\madhe\\OneDrive\\Desktop\\personal docs', 'filename': 'Pan.jpg', 'category': 'Image', 'element_id': 'd48cd56115cf2c0098b16bb42ca2ddf7'}, page_content='')]
